# %%
import numpy as np 
import matplotlib.pyplot as plt 

n = 400
sigma1 = 1
mu1 = 0 
sigma2 = 4
mu2 = 0 

x1 = np.random.uniform(-np.sqrt(12*sigma1),np.sqrt(12*sigma1),n)
x2 = np.random.normal(mu2,sigma2,n) 

plt.scatter(x1,x2)
